# %% [markdown]
# # Visualizations

# %% [markdown]
# **Example 0:** Importing the required packages.  `% matplotlib` is a directive to show plots in the notebook. These are standard imports required for display.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Example 1:** Creating a plural of numbers

# %%
x = np.arange(0, 10, .5)
y = x ** 2

plt.plot(x,y);

# %% [markdown]
# **Example 2:** Same data except with a scatter plot

# %%
x = np.arange(0, 10, .5)
y = x ** 2

plt.scatter(x,y);

# %% [markdown]
# ** Example 3:** Same kind of plot but with `linspace`, use Jupyter's tooltip to see what `linspace` does.

# %%
x = np.linspace(0, 10, 50)
y = x ** 2

plt.plot(x, y);
